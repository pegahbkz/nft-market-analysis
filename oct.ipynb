# %%
# import the OpenseaAPI object from the opensea module
from opensea import OpenseaAPI

# create an object to interact with the Opensea API (need an api key)
api = OpenseaAPI(apikey="d69caa20869348d7a5cb0abe72885ef1")

# %%
from opensea import utils as opensea_utils
import json
import csv
from flatten_json import flatten

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 1, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 1, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct1.json",
        event_type="successful",
)

    with open('23-oct1.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 2, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 2, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct2.json",
        event_type="successful",
)

    with open('23-oct2.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 3, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 3, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct3.json",
        event_type="successful",
)

    with open('23-oct3.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 4, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 4, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct4.json",
        event_type="successful",
)

    with open('23-oct4.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 5, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 5, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct5.json",
        event_type="successful",
)

    with open('23-oct5.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 6, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 6, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct6.json",
        event_type="successful",
)

    with open('23-oct6.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 7, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 7, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct7.json",
        event_type="successful",
)

    with open('23-oct7.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 8, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 8, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct8.json",
        event_type="successful",
)

    with open('23-oct8.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 9, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 9, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct8.json",
        event_type="successful",
)

    with open('23-oct8.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 10, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 10, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct10.json",
        event_type="successful",
)

    with open('23-oct10.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 11, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 11, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct11.json",
        event_type="successful",
)

    with open('23-oct11.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 12, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 12, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct12.json",
        event_type="successful",
)

    with open('23-oct12.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 13, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 13, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct13.json",
        event_type="successful",
)

    with open('23-oct13.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 14, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 14, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct14.json",
        event_type="successful",
)

    with open('23-oct14.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 15, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 15, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct15.json",
        event_type="successful",
)

    with open('23-oct15.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 16, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 16, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct16.json",
        event_type="successful",
)

    with open('23-oct16.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 17, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 17, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct17.json",
        event_type="successful",
)

    with open('23-oct17.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 18, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 18, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct18.json",
        event_type="successful",
)

    with open('23-oct18.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 19, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 19, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct19.json",
        event_type="successful",
)

    with open('23-oct19.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 20, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 20, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct20.json",
        event_type="successful",
)

    with open('23-oct20.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 21, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 21, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct21.json",
        event_type="successful",
)

    with open('23-oct21.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 22, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 22, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct22.json",
        event_type="successful",
)

    with open('23-oct22.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 23, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 23, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct23.json",
        event_type="successful",
)

    with open('23-oct23.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# ...

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 24, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 24, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct24.json",
        event_type="successful",
)

    with open('23-oct24.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:761, in HTTPResponse._update_chunk_length(self)
#     760 try:
# --> 761     self.chunk_left = int(line, 16)
#     762 except ValueError:
#     763     # Invalid chunked protocol response, abort.
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# ...

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 25, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 25, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct25.json",
        event_type="successful",
)

    with open('23-oct25.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 26, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 26, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct26.json",
        event_type="successful",
)

    with open('23-oct26.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:761, in HTTPResponse._update_chunk_length(self)
#     760 try:
# --> 761     self.chunk_left = int(line, 16)
#     762 except ValueError:
#     763     # Invalid chunked protocol response, abort.
#
# ValueError: invalid literal for int() with base 16: b''
#
# During handling of the above exception, another exception occurred:
#
# InvalidChunkLength                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/response.py:444, in HTTPResponse._error_catcher(self)
#     443 try:
# --> 444     yield
#     446 except SocketTimeout:
#     447     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     448     # there is yet no clean way to get at it from this context.
#
# ...

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 27, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 27, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct27.json",
        event_type="successful",
)

    with open('23-oct27.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 28, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 28, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct28.json",
        event_type="successful",
)

    with open('23-oct28.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 29, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 29, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct29.json",
        event_type="successful",
)

    with open('23-oct29.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 30, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 30, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct30.json",
        event_type="successful",
)

    with open('23-oct30.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()

# %%
count = 0

for j in range(24):
    period_start = opensea_utils.datetime_utc(2023, 10, 31, j, 0)
    period_end = opensea_utils.datetime_utc(2023, 10, 31, j, 59)

    result = api.events(
        occurred_after=period_start,
        occurred_before=period_end,
        limit=300,
        export_file_name="23-oct31.json",
        event_type="successful",
)

    with open('23-oct31.json') as json_file:
        jsondata = json.load(json_file)


        data_file = open('23-oct.csv', 'a', newline='')
        csv_writer = csv.writer(data_file)

        count = 0

        for data in jsondata["asset_events"]:
            data = flatten(data)
            if count == 0:
                header = data.keys()
                csv_writer.writerow(header)
                count += 1
            csv_writer.writerow(data.values())

        data_file.close()
