# %%
import pandas as pd

# %%
data1 = pd.read_csv('jan23 copy.csv', low_memory=False)
data1
# Out:
#          asset_id  asset_token_id  asset_num_sales  \
# 0       945584035        112997.0                2
# 1       945583484        112973.0                2
# 2       945583490        112977.0                2
# 3       945584040        112993.0                2
# 4       941916132          8114.0                2
# ...           ...             ...              ...
# 126190   23140429          7305.0               21
# 126191   23141356          7941.0               53
# 126192   23142016          8477.0                5
# 126193  417278586             1.0              104
# 126194  417278586             1.0              104
#
#                    asset_description  \
# 0       NFT Node for tier => OG THOR
# 1       NFT Node for tier => OG THOR
# 2       NFT Node for tier => OG THOR
# 3       NFT Node for tier => OG THOR
# 4       NFT Node for tier => OG THOR
# ...                              ...
# 126190                           NaN
# 126191                           NaN
# ...

# %%
data2 = pd.read_csv('feb23.csv', low_memory=False)
data2
# Out:
#           asset_id  asset_token_id  asset_num_sales  \
# 0        662763581    1.553900e+04                1
# 1        662763585    1.554000e+04                1
# 2        662763495    1.521400e+04                1
# 3        903099326    1.690000e+02                1
# 4        903099335    2.317000e+03                1
# ...            ...             ...              ...
# 150208   752227589    2.000000e+00             1331
# 150209   634877613    5.477000e+03                1
# 150210   634877665    5.491000e+03                1
# 150211  1073145083    7.430000e+76                3
# 150212  1073492952    2.700000e+76                1
#
#                                         asset_description  \
# 0       Wynd of Wyrmnd born with Fire element and Vici...
# 1       Wynd of Wyrmnd born with Wind element and Vici...
# 2       Rider of Mercenary born with Light element and...
# 3       Summoner's Book can summon heroes for use in C...
# ...

# %%
data3 = pd.read_csv('mar23.csv', low_memory=False)
data3
# Out:
#             asset_id  asset_token_id  asset_num_sales  \
# 0       7.937108e+08    1.520215e+06                1
# 1       8.097448e+08    1.616350e+06                1
# 2       1.005052e+09    3.751424e+06                1
# 3       1.076149e+09    4.762468e+06                1
# 4       1.123779e+09    5.851247e+06                1
# ...              ...             ...              ...
# 159118  1.073579e+09    9.760000e+02                1
# 159119  1.129494e+09    3.760000e+02                1
# 159120  1.129494e+09    4.080000e+02                6
# 159121  1.129494e+09    4.000000e+02                1
# 159122  1.126929e+09    3.620000e+76                2
#
#                                         asset_description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
data4 = pd.read_csv('apr23.csv', low_memory=False)
data4
# Out:
#           asset_id asset_token_id  asset_num_sales  \
# 0       1150283787          18400                1
# 1       1037876475        4013166                1
# 2       1099714550        5088191                1
# 3       1109954652        5404903                1
# 4       1120139651        5782999                1
# ...            ...            ...              ...
# 108074    16640848           6724               21
# 108075  1102555866           6884               77
# 108076  1115124806           8518               27
# 108077    23134600           3266                2
# 108078  1012971663              2               73
#
#                                         asset_description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
data5 = pd.read_csv('may23.csv', low_memory=False)
data5
# Out:
#          asset_id asset_token_id  asset_num_sales  \
# 0      1109652552        5381982                1
# 1      1109656564        5382427                1
# 2      1205052050         381554                2
# 3      1205051892         551746                1
# 4      1195318711        4600000                2
# ...           ...            ...              ...
# 41254  1119750122           5967               74
# 41255  1096531838           6496               16
# 41256    16715335           6834              108
# 41257  1109304070           9419               42
# 41258    20860588            717               70
#
#                                        asset_description  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Following Brahimi's individual effort, the bal...
# 3      Xavi Aguado is a legend in the history of Real...
# 4                                                    NaN
# ...

# %%
data6 = pd.read_csv('jun23.csv', low_memory=False)
data6
# Out:
#             asset_id  asset_token_id  asset_num_sales  \
# 0       1.141070e+09       6080165.0                1
# 1       1.199735e+09       6587125.0                1
# 2       1.239638e+09       6972560.0                1
# 3       1.121445e+09       5800940.0                1
# 4       1.111895e+09       5454216.0                1
# ...              ...             ...              ...
# 157084  1.671534e+07          6834.0              108
# 157085  1.230020e+09          9662.0               43
# 157086  1.727529e+07          2905.0               15
# 157087  1.110501e+09          5682.0               55
# 157088  1.533587e+08          2955.0               12
#
#                                         asset_description  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
data7 = pd.read_csv('jul23.csv', low_memory=False)
data7
# Out:
#             asset_id  asset_token_id  asset_num_sales  \
# 0       1.295411e+09    3.222300e+05                1
# 1       6.927326e+08    6.510000e+76                1
# 2       1.328811e+09    1.400000e+01                1
# 3       1.328811e+09    3.000000e+01                1
# 4       1.328811e+09    8.900000e+01                1
# ...              ...             ...              ...
# 171492  2.314018e+07    7.174000e+03                2
# 171493  2.310644e+07    4.160000e+02                1
# 171494  2.313866e+07    6.109000e+03                3
# 171495  2.313235e+07    2.150000e+03               18
# 171496  2.314296e+07    9.281000e+03                4
#
#                                         asset_description  \
# 0       zkBridge and zk light client are proud to anno...
# 1                                                  276666
# 2                                                     NaN
# 3                                                     NaN
# ...

# %%
data8 = pd.read_csv('aug23.csv', low_memory=False)
data8
# Out:
#             asset_id asset_token_id  asset_num_sales  \
# 0       7.514043e+08          67846                2
# 1       1.204784e+09          45761                1
# 2       1.405450e+09         974052                1
# 3       1.370212e+09             66              192
# 4       1.370212e+09             66              192
# ...              ...            ...              ...
# 172938  9.841365e+08              0            16154
# 172939  1.452057e+09           9383                3
# 172940  1.994277e+07           9442                4
# 172941  1.994277e+07           9442                4
# 172942  2.668143e+07       78000579                6
#
#                                         asset_description  \
# 0                                   Halloween shorts 2022
# 1                       XENFT: XEN Crypto Minting Torrent
# 2       Pandra is an omnichain NFT collection built wi...
# 3                                                     NaN
# ...

# %%
data9 = pd.read_csv('sep23.csv', low_memory=False)
data9
# Out:
#             asset_id asset_token_id  asset_num_sales  \
# 0       1.383486e+09             87               86
# 1       1.115791e+09        5635368                2
# 2       1.377515e+09         650507                1
# 3       1.377513e+09         650426                1
# 4       1.383486e+09             87               86
# ...              ...            ...              ...
# 162684  1.115253e+09           8363                1
# 162685  1.687465e+07           3042                1
# 162686  1.097156e+09           2996               20
# 162687  1.119750e+09           5967               74
# 162688  6.188265e+08            340                1
#
#                                         asset_description  \
# 0                                                     NaN
# 1                                                     NaN
# 2       Pandra is an omnichain NFT collection built wi...
# 3       Pandra is an omnichain NFT collection built wi...
# ...

# %%
data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9], ignore_index=True)

# %%
data['asset_asset_contract_asset_contract_type_semi'] = data['asset_asset_contract_asset_contract_type_semi'].replace({'TRUE': 1, 'FALSE': 0})
data['asset_collection_is_rarity_enabled'] = data['asset_collection_is_rarity_enabled'].replace({'TRUE': 1, 'FALSE': 0})
data['asset_collection_is_creator_fees_enforced'] = data['asset_collection_is_creator_fees_enforced'].replace({'TRUE': 1, 'FALSE': 0})

# %%
data['asset_description'] = data['asset_description'].astype(str)
data['asset_asset_contract_description'] = data['asset_asset_contract_description'].astype(str)

# %%
new_column = []
#data2 = pd.DataFrame()
#data3 = pd.DataFrame()

for index, row in data.iterrows():
    if row['asset_description'] == '1' or row['asset_asset_contract_description'] == '1':
        new_column.append(1)
        #data2.append(row)
    else:
        new_column.append(0)
        #data3.append(row)

data['generator'] = new_column

# %%
sum(data['generator'])
# Out:
# 126860

# %%
data = data.drop(['asset_description','asset_asset_contract_description'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1249087 entries, 0 to 1249086
# Data columns (total 24 columns):
#  #   Column                                            Non-Null Count    Dtype
# ---  ------                                            --------------    -----
#  0   asset_id                                          1249075 non-null  float64
#  1   asset_token_id                                    1249087 non-null  object
#  2   asset_num_sales                                   1249087 non-null  int64
#  3   asset_asset_contract_asset_contract_type_semi     1249053 non-null  float64
#  4   asset_asset_contract_created_date                 1249087 non-null  int64
#  5   Copy asset_asset_contract_created_date_month      1249087 non-null  int64
#  6   asset_asset_contract_owner                        1141253 non-null  object
#  7   asset_asset_contract_dev_seller_fee_basis_points  1249087 non-null  object
# ...

# %%
data.dropna(inplace=True)

# %%
data = data.drop(['asset_id','asset_token_id'], axis=1)

# %%
data['asset_asset_contract_dev_seller_fee_basis_points'] = data['asset_asset_contract_dev_seller_fee_basis_points'].astype(int)
data['asset_asset_contract_seller_fee_basis_points'] = data['asset_asset_contract_seller_fee_basis_points'].astype(int)
data['asset_collection_dev_seller_fee_basis_points'] = data['asset_collection_dev_seller_fee_basis_points'].astype(int)
data['transaction_transaction_index'] = data['transaction_transaction_index'].astype(int)
data['asset_asset_contract_owner'] = data['asset_asset_contract_owner'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1141159 entries, 391 to 1249086
# Data columns (total 22 columns):
#  #   Column                                            Non-Null Count    Dtype
# ---  ------                                            --------------    -----
#  0   asset_num_sales                                   1141159 non-null  int64
#  1   asset_asset_contract_asset_contract_type_semi     1141159 non-null  float64
#  2   asset_asset_contract_created_date                 1141159 non-null  int64
#  3   Copy asset_asset_contract_created_date_month      1141159 non-null  int64
#  4   asset_asset_contract_owner                        1141159 non-null  int64
#  5   asset_asset_contract_dev_seller_fee_basis_points  1141159 non-null  int64
#  6   asset_asset_contract_seller_fee_basis_points      1141159 non-null  int64
#  7   asset_collection_dev_seller_fee_basis_points      1141159 non-null  int64
# ...

# %%
data['asset_collection_dev_seller_fee_basis_points'] = data['asset_collection_dev_seller_fee_basis_points'].astype(int)

# %%
data.payment_token_symbol.value_counts()
# Out:
# ETH      588226
# MATIC    288402
# WETH     191166
# BNB       42729
# WBNB      11057
# MAGIC      8900
# WAVAX      7682
# KLAY       2843
# AVAX        154
# Name: payment_token_symbol, dtype: int64

# %%
data = data.join(pd.get_dummies(data.payment_token_symbol)).drop(['payment_token_symbol'], axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1141159 entries, 391 to 1249086
# Data columns (total 30 columns):
#  #   Column                                            Non-Null Count    Dtype
# ---  ------                                            --------------    -----
#  0   asset_num_sales                                   1141159 non-null  int64
#  1   asset_asset_contract_asset_contract_type_semi     1141159 non-null  float64
#  2   asset_asset_contract_created_date                 1141159 non-null  int64
#  3   Copy asset_asset_contract_created_date_month      1141159 non-null  int64
#  4   asset_asset_contract_owner                        1141159 non-null  int64
#  5   asset_asset_contract_dev_seller_fee_basis_points  1141159 non-null  int64
#  6   asset_asset_contract_seller_fee_basis_points      1141159 non-null  int64
#  7   asset_collection_dev_seller_fee_basis_points      1141159 non-null  int64
# ...

# %%
df2 = pd.DataFrame(columns=data.columns)

# Store the dtypes of original_df columns
dtypes_dict = data.dtypes.to_dict()

# Iterate through the original DataFrame
indices_to_remove = []  # To store indices of rows to be removed
for index, row in data.iterrows():
    if row['generator'] == 1:
        # Add rows where 'a' is equal to 1 to df2
        df2 = df2.append(row, ignore_index=True)
        indices_to_remove.append(index)  # Store indices to remove

# Explicitly cast the types in df2 to match original_df
for col, dtype in dtypes_dict.items():
    df2[col] = df2[col].astype(dtype)
    
data = data.drop(indices_to_remove)
# Out:
# /var/folders/gt/7kmf603j77q1btgzzyyg2lch0000gn/T/ipykernel_1189/2243466480.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(row, ignore_index=True)

# %%
df4 = data.sample(frac=0.2, random_state=42)

# %%
df = pd.concat([df2, df4], ignore_index=True)

# %%
year23g = []
price23g = []
year23h = []
price23h = []

for i in range(0, 9):
    year23g.append(0)
    price23g.append(0)

    year23h.append(0)
    price23h.append(0)

for index, row in df.iterrows():
    for j in range(1, 10):
        if row['transaction_timestamp'] == j:
            if row['generator'] == 1:
                year23g[j-1] += 1
                price23g[j-1] += row['total_price']
            else:
                year23h[j-1] += 1
                price23h[j-1] += row['total_price']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
price23h
# Out:
# [6.40927040613005e+16,
#  4.174390740956638e+16,
#  6234508851.0,
#  4108202005.0,
#  1711288248.0,
#  9366872615.0,
#  20650792924.0,
#  12018948573.0,
#  8527718188.0]

# %%
price23g
# Out:
# [3154401206946948.0,
#  3647502054893187.0,
#  2228927613.0,
#  1180816301.0,
#  433455101.0,
#  2017028169.0,
#  1250917046.0,
#  2014084664.0,
#  1595612447.0]

# %%
generative = []
handdrawn = []
for index, row in data.iterrows():
    if row['generator']:
        generative.append(row['total_price'])
    else:
        handdrawn.append(row['total_price'])

# %%
dataframe = pd.DataFrame({'Name': ['generative', 'handdrawn'], 
                          'value': [57235415241.21706, 51762987170.94368]}) 
  
# Plotting the pie chart for above dataframe 
dataframe.groupby(['Name']).sum().plot(kind='pie', y='value')
# Out:
# <AxesSubplot: ylabel='value'>

# %%
57235415241.21706 / 51762987170.94368
# Out:
# 1.1057208706329305
